# %% [markdown]
# <a href="https://colab.research.google.com/github/LUCKYHARSHA001/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the diverse skill sets needed for successful AI implementation, from foundational to strategic:
#
# *   **Foundation (Data & Infrastructure):** Skills in data engineering, MLOps, and managing the core compute resources and data pipelines required to enable AI.
# *   **Building Models:** Expertise in machine learning engineering, data science, and the development, training, and evaluation of AI models.
# *   **Applying & Integrating AI:** Skills in prompt engineering, software development, and integrating AI models into real-world applications and products.
# *   **Strategy & Responsible AI:** Guiding AI initiatives with business strategy, product management, and ensuring ethical deployment, governance, and societal responsibility.
